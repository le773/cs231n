# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup
import numpy as np
import matplotlib.pyplot as plt
import time

from cs231n.classifiers.four_neural_net import FourLayerNet
from cs231n.classifiers.four_neural_net import batchNormal

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (15.0, 12.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size1 = 32
hidden_size2 = 24
hidden_size3 = 16
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)
    return FourLayerNet(input_size, hidden_size1, hidden_size2, hidden_size3, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[nan nan nan]
#  [nan nan nan]
#  [nan nan nan]
#  [nan nan nan]
#  [nan nan nan]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# nan
# E:\OctaveProject\convnet-layers\cs231n\classifiers\four_neural_net.py:10: RuntimeWarning: invalid value encountered in true_divide
#   X_input /= np.std(X_input, axis=0)

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# nan
# E:\OctaveProject\convnet-layers\cs231n\classifiers\four_neural_net.py:10: RuntimeWarning: invalid value encountered in true_divide
#   X_input /= np.std(X_input, axis=0)
# E:\OctaveProject\convnet-layers\cs231n\classifiers\four_neural_net.py:185: RuntimeWarning: invalid value encountered in greater
#   p2_tmp = (relu_tmp3 > 0.01*relu_tmp3) * p2_tmp
# E:\OctaveProject\convnet-layers\cs231n\classifiers\four_neural_net.py:195: RuntimeWarning: invalid value encountered in greater
#   p1_tmp = (relu_tmp2 > 0.01*relu_tmp2) * p1_tmp

# %%
print(net.loss(X, y, reg=0.05)[1].keys())
# Out:
# dict_keys(['W2', 'b2', 'D2', 'e2', 'D1', 'e1', 'W1', 'b1'])
# E:\OctaveProject\convnet-layers\cs231n\classifiers\four_neural_net.py:10: RuntimeWarning: invalid value encountered in true_divide
#   X_input /= np.std(X_input, axis=0)
# E:\OctaveProject\convnet-layers\cs231n\classifiers\four_neural_net.py:185: RuntimeWarning: invalid value encountered in greater
#   p2_tmp = (relu_tmp3 > 0.01*relu_tmp3) * p2_tmp
# E:\OctaveProject\convnet-layers\cs231n\classifiers\four_neural_net.py:195: RuntimeWarning: invalid value encountered in greater
#   p1_tmp = (relu_tmp2 > 0.01*relu_tmp2) * p1_tmp

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# E:\OctaveProject\convnet-layers\cs231n\classifiers\four_neural_net.py:10: RuntimeWarning: invalid value encountered in true_divide
#   X_input /= np.std(X_input, axis=0)
# E:\OctaveProject\convnet-layers\cs231n\classifiers\four_neural_net.py:185: RuntimeWarning: invalid value encountered in greater
#   p2_tmp = (relu_tmp3 > 0.01*relu_tmp3) * p2_tmp
# E:\OctaveProject\convnet-layers\cs231n\classifiers\four_neural_net.py:195: RuntimeWarning: invalid value encountered in greater
#   p1_tmp = (relu_tmp2 > 0.01*relu_tmp2) * p1_tmp
# W2 max relative error: nan
# b2 max relative error: nan
# D2 max relative error: nan
# e2 max relative error: nan
# D1 max relative error: nan
# e1 max relative error: nan
# W1 max relative error: nan
# b1 max relative error: nan

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# iterations_per_epoch:1 num_train:5 batch_size:200 num_iters:100
# loss is enough, stop and validation
# Final training loss:  0.9996352879737876

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=45000, num_validation=5000, num_test=5000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
# X_train = batchNormal(X_train)
# # y_train = batchNormal(y_train)
# X_val = batchNormal(X_val)
# # y_val = batchNormal(y_val)
# X_test = batchNormal(X_test)
# # y_test = batchNormal(y_test)
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (45000, 3072)
# Train labels shape:  (45000,)
# Validation data shape:  (5000, 3072)
# Validation labels shape:  (5000,)
# Test data shape:  (5000, 3072)
# Test labels shape:  (5000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %% [markdown]
# ### 计算损失值
# 参考：[CS231n 2018 最小的神经网络案例学习](https://blog.csdn.net/tech0ne/article/details/80564239)

# %%
def preTrain(stats):
    # Plot the loss function and train / validation accuracies
    plt.subplot(2, 1, 1)
    plt.plot(stats['loss_history'])
    plt.title('Loss history')
    plt.xlabel('Iteration')
    plt.ylabel('Loss')

    plt.subplot(2, 1, 2)
    t1, = plt.plot(stats['train_acc_history'], color='r',label='train')
    t2, = plt.plot(stats['val_acc_history'], color='g', label='val')
    plt.title('Classification accuracy history')
    plt.xlabel('Epoch')
    plt.ylabel('accuracy')
    plt.legend(handles = [t1, t2,], labels=['train', 'val'])
    plt.show()

# %%
input_size = 32 * 32 * 3
hidden_size1 = 1024
hidden_size2 = 512
hidden_size3 = 128
num_classes = 10
# Train the network
learning_rates = [2.5e-2]#, 3e-3, 2e-3
std_devs=[6e-2]#, 5e-3, 5e-2
regularization_strengths = [5e-1]
learning_rate = 1e-2
num_iter=600

for std_dev in std_devs:
    net = None
    net = FourLayerNet(input_size, hidden_size1, hidden_size2, hidden_size3, num_classes, std=std_dev)
#     for learning_rate in learning_rates:
    stats = net.train(X_train, y_train, X_val, y_val,
                num_iters=num_iter, batch_size=400,
                learning_rate=learning_rate, learning_rate_decay=0.95,
                reg=5e-1, verbose=True)
    # Predict on the validation set
    val_acc = (net.predict(X_val) == y_val).mean()
    print('Validation accuracy: ', val_acc)
    preTrain(stats)
# Out:
# iterations_per_epoch:112.5 num_train:45000 batch_size:400 num_iters:600
# iteration 0 / 600: loss 3306.180348
# iteration 100 / 600: loss 1278.532406
# iteration 200 / 600: loss 496.259521
# iteration 300 / 600: loss 200.160450
# iteration 400 / 600: loss 82.370416
# iteration 500 / 600: loss 35.316738
# Validation accuracy:  0.2932

# %%
# test_acc = (net.predict(X_test) == y_test).mean()
# print('Test accuracy: ', test_acc)

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
if False:
    plt.subplot(2, 1, 1)
    plt.plot(stats['loss_history'])
    plt.title('Loss history')
    plt.xlabel('Iteration')
    plt.ylabel('Loss')

    plt.subplot(2, 1, 2)
    t1, = plt.plot(stats['train_acc_history'], color='r',label='train')
    t2, = plt.plot(stats['val_acc_history'], color='g', label='val')
    plt.title('Classification accuracy history')
    plt.xlabel('Epoch')
    plt.ylabel('accuracy')
    plt.legend(handles = [t1, t2,], labels=['train', 'val'])
    plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
import random

best_val = -1
best_stats = None
bast_net = None
node_net = []
regularization_strengths = [5e-1]
learning_rates = [2.5e-2]
std_devs=[5e-2]
learning_rate_decays = [0.95]
results = {}
iters = 10000
hidden_size1 = 1024
hidden_size2 = 512
hidden_size3 = 256
max_count = 10
for count in range(max_count):
    for hidden_size1 in [1024]:
        for hidden_size2 in [512]:
            if hidden_size1 == hidden_size2:
                continue
            for std_dev in std_devs:
                for lr in learning_rates:
                    for rs in regularization_strengths:
                        for learning_rate_decay in learning_rate_decays:
                            lr = 2**random.uniform(-10,-1)
#                             std_dev = 2**random.uniform(-10,-1)
                            t0 = time.time()
                            net = FourLayerNet(input_size, hidden_size1, hidden_size2, hidden_size3, num_classes, std=std_dev)
                            node_net.append(net)
                            stats = net.train(X_train, y_train, X_val, y_val,
                                num_iters=iters, learning_rate=lr, batch_size=200, learning_rate_decay=learning_rate_decay,
                                reg=rs, verbose=True)

                            mask = np.random.choice(X_train.shape[0], 200, replace=True)
                            X_batch = X_train[mask]
                            y_batch = y_train[mask]
                            acc_train = (net.predict(X_batch) == y_batch).mean()

                            mask = np.random.choice(X_val.shape[0], 400, replace=True)
                            X_val_batch= X_val[mask]
                            y_val_batch = y_val[mask]
                            acc_val = (net.predict(X_val_batch) == y_val_batch).mean()
                            
                            results[(lr,rs,acc_train, acc_val, std_dev, learning_rate_decay)] = (lr,rs,acc_train, acc_val, std_dev, learning_rate_decay)
                            
                            t1 = time.time()
                            localtime = time.asctime(time.localtime(t1))
                            print('count:', count, '-->localtime:',localtime, '<--- time:', t1-t0)
                            if best_val < acc_val:
                                print('-----------vvv--------------')
                                print('   acc_val:', acc_val)
                                print('   std_dev:', std_dev)
                                best_std_dev = std_dev
                                best_stats = stats
                                best_val = acc_val
                                best_net = net
                                best_hidden1 = hidden_size1
                                best_hidden2 = hidden_size2
                                best_hidden3 = hidden_size3
                                best_std_dev = std_dev
                                best_lr = lr
                                best_rg = rs
                                best_learning_rate_decay = learning_rate_decay
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# iterations_per_epoch:225.0 num_train:45000 batch_size:200 num_iters:10000
# iteration 0 / 10000: loss 2298.746763
# iteration 100 / 10000: loss 1679.763473
# iteration 200 / 10000: loss 1228.654291
# iteration 300 / 10000: loss 909.397178
# iteration 400 / 10000: loss 676.048707
# iteration 500 / 10000: loss 506.343047
# iteration 600 / 10000: loss 382.198342
# iteration 700 / 10000: loss 289.661398
# iteration 800 / 10000: loss 221.918609
# iteration 900 / 10000: loss 170.118473
# iteration 1000 / 10000: loss 132.281632
# iteration 1100 / 10000: loss 102.970356
# iteration 1200 / 10000: loss 80.915064
# iteration 1300 / 10000: loss 63.941354
# iteration 1400 / 10000: loss 50.935253
# iteration 1500 / 10000: loss 40.810800
# iteration 1600 / 10000: loss 32.854157
# iteration 1700 / 10000: loss 26.858523
# iteration 1800 / 10000: loss 21.888875
# iteration 1900 / 10000: loss 18.226986
# iteration 2000 / 10000: loss 15.222657
# iteration 2100 / 10000: loss 12.632909
# iteration 2200 / 10000: loss 10.733238
# iteration 2300 / 10000: loss 9.136731
# iteration 2400 / 10000: loss 7.894982
# iteration 2500 / 10000: loss 6.847296
# iteration 2600 / 10000: loss 6.100116
# iteration 2700 / 10000: loss 5.497087
# iteration 2800 / 10000: loss 4.809056
# iteration 2900 / 10000: loss 4.316964
# iteration 3000 / 10000: loss 4.043982
# iteration 3100 / 10000: loss 3.647947
# loss descent too slow 100 loss ago：3.5990919645848525  loss:3.523328278228367
# count: 0 -->localtime: Sat Jun 23 22:10:09 2018 <--- time: 615.9824547767639
# -----------vvv--------------
#    acc_val: 0.135
#    std_dev: 0.05
# iterations_per_epoch:225.0 num_train:45000 batch_size:200 num_iters:10000
# iteration 0 / 10000: loss 2299.338529
# iteration 100 / 10000: loss 987.659119
# iteration 200 / 10000: loss 425.441551
# iteration 300 / 10000: loss 189.664644
# iteration 400 / 10000: loss 85.925978
# iteration 500 / 10000: loss 40.331694
# iteration 600 / 10000: loss 19.749461
# iteration 700 / 10000: loss 10.282423
# iteration 800 / 10000: loss 5.906281
# iteration 900 / 10000: loss 3.800061
# iteration 1000 / 10000: loss 2.743791
# iteration 1100 / 10000: loss 2.410220
# iteration 1200 / 10000: loss 2.067244
# loss descent too slow 100 loss ago：2.1577755022206553  loss:2.0709509816844616
# count: 1 -->localtime: Sat Jun 23 22:14:09 2018 <--- time: 239.96408677101135
# -----------vvv--------------
#    acc_val: 0.155
#    std_dev: 0.05
# iterations_per_epoch:225.0 num_train:45000 batch_size:200 num_iters:10000
# iteration 0 / 10000: loss 2295.331798
# iteration 100 / 10000: loss 2063.822597
# iteration 200 / 10000: loss 1856.321153
# iteration 300 / 10000: loss 1676.455762
# iteration 400 / 10000: loss 1516.215270
# iteration 500 / 10000: loss 1374.802026
# iteration 600 / 10000: loss 1249.606242
# iteration 700 / 10000: loss 1137.248561
# iteration 800 / 10000: loss 1038.911150
# iteration 900 / 10000: loss 948.998803
# iteration 1000 / 10000: loss 870.819034
# iteration 1100 / 10000: loss 799.151476
# iteration 1200 / 10000: loss 735.569974
# iteration 1300 / 10000: loss 677.891827
# iteration 1400 / 10000: loss 626.044897
# iteration 1500 / 10000: loss 579.392645
# iteration 1600 / 10000: loss 536.683225
# iteration 1700 / 10000: loss 498.743748
# iteration 1800 / 10000: loss 463.204572
# iteration 1900 / 10000: loss 431.978453
# iteration 2000 / 10000: loss 402.949175
# iteration 2100 / 10000: loss 376.667699
# iteration 2200 / 10000: loss 352.512755
# iteration 2300 / 10000: loss 330.472326
# iteration 2400 / 10000: loss 310.360521
# iteration 2500 / 10000: loss 291.591921
# iteration 2600 / 10000: loss 274.701482
# iteration 2700 / 10000: loss 258.759781
# iteration 2800 / 10000: loss 244.532270
# iteration 2900 / 10000: loss 231.071406
# iteration 3000 / 10000: loss 218.712270
# iteration 3100 / 10000: loss 207.302255
# iteration 3200 / 10000: loss 196.670183
# iteration 3300 / 10000: loss 186.942376
# iteration 3400 / 10000: loss 177.681535
# iteration 3500 / 10000: loss 169.289759
# iteration 3600 / 10000: loss 161.295577
# iteration 3700 / 10000: loss 154.143890
# iteration 3800 / 10000: loss 147.101664
# iteration 3900 / 10000: loss 140.774872
# iteration 4000 / 10000: loss 134.731261
# iteration 4100 / 10000: loss 129.228277
# iteration 4200 / 10000: loss 123.870448
# iteration 4300 / 10000: loss 118.938707
# iteration 4400 / 10000: loss 114.333237
# iteration 4500 / 10000: loss 109.930326
# iteration 4600 / 10000: loss 105.989086
# iteration 4700 / 10000: loss 102.052082
# iteration 4800 / 10000: loss 98.491159
# iteration 4900 / 10000: loss 95.069974
# iteration 5000 / 10000: loss 91.828474
# iteration 5100 / 10000: loss 88.855763
# iteration 5200 / 10000: loss 85.908269
# iteration 5300 / 10000: loss 83.220864
# iteration 5400 / 10000: loss 80.666788
# iteration 5500 / 10000: loss 78.271899
# iteration 5600 / 10000: loss 75.853959
# iteration 5700 / 10000: loss 73.756040
# iteration 5800 / 10000: loss 71.678740
# iteration 5900 / 10000: loss 69.690476
# iteration 6000 / 10000: loss 67.829103
# iteration 6100 / 10000: loss 66.036184
# iteration 6200 / 10000: loss 64.411481
# iteration 6300 / 10000: loss 62.709445
# iteration 6400 / 10000: loss 61.226069
# iteration 6500 / 10000: loss 59.777387
# iteration 6600 / 10000: loss 58.339283
# iteration 6700 / 10000: loss 57.030832
# iteration 6800 / 10000: loss 55.837892
# iteration 6900 / 10000: loss 54.552214
# iteration 7000 / 10000: loss 53.380129
# iteration 7100 / 10000: loss 52.344387
# iteration 7200 / 10000: loss 51.146268
# iteration 7300 / 10000: loss 50.171230
# iteration 7400 / 10000: loss 49.236026
# iteration 7500 / 10000: loss 48.273440
# iteration 7600 / 10000: loss 47.439426
# iteration 7700 / 10000: loss 46.556174
# iteration 7800 / 10000: loss 45.709036
# iteration 7900 / 10000: loss 44.902394
# iteration 8000 / 10000: loss 44.158902
# iteration 8100 / 10000: loss 43.443808
# iteration 8200 / 10000: loss 42.715445
# iteration 8300 / 10000: loss 42.134999
# iteration 8400 / 10000: loss 41.372818
# iteration 8500 / 10000: loss 40.794747
# iteration 8600 / 10000: loss 40.186152
# iteration 8700 / 10000: loss 39.721363
# iteration 8800 / 10000: loss 39.127976
# iteration 8900 / 10000: loss 38.622549
# iteration 9000 / 10000: loss 38.057791
# iteration 9100 / 10000: loss 37.578320
# iteration 9200 / 10000: loss 37.021777
# iteration 9300 / 10000: loss 36.617685
# iteration 9400 / 10000: loss 36.123470
# iteration 9500 / 10000: loss 35.707437
# iteration 9600 / 10000: loss 35.261291
# iteration 9700 / 10000: loss 34.899107
# iteration 9800 / 10000: loss 34.562473
# iteration 9900 / 10000: loss 34.113640
# count: 2 -->localtime: Sat Jun 23 22:33:33 2018 <--- time: 1163.6357758045197
# -----------vvv--------------
#    acc_val: 0.34
#    std_dev: 0.05
# iterations_per_epoch:225.0 num_train:45000 batch_size:200 num_iters:10000
# iteration 0 / 10000: loss 2298.660725
# loss ascend ++ old_loss：2.983437129707785  loss:3.3925612940546506
# count: 3 -->localtime: Sat Jun 23 22:33:41 2018 <--- time: 8.300572156906128
# iterations_per_epoch:225.0 num_train:45000 batch_size:200 num_iters:10000
# iteration 0 / 10000: loss 2296.143020
# iteration 100 / 10000: loss 1043.495182
# iteration 200 / 10000: loss 475.455122
# iteration 300 / 10000: loss 223.530575
# iteration 400 / 10000: loss 106.672948
# iteration 500 / 10000: loss 52.360491
# iteration 600 / 10000: loss 26.672074
# iteration 700 / 10000: loss 14.090412
# iteration 800 / 10000: loss 8.091178
# iteration 900 / 10000: loss 5.080854
# iteration 1000 / 10000: loss 3.559721
# iteration 1100 / 10000: loss 2.734317
# iteration 1200 / 10000: loss 2.252545
# iteration 1300 / 10000: loss 2.022352
# loss descent too slow 100 loss ago：2.234529734833399  loss:2.1462567255288194
# count: 4 -->localtime: Sat Jun 23 22:37:29 2018 <--- time: 228.050922870636
# iterations_per_epoch:225.0 num_train:45000 batch_size:200 num_iters:10000
# iteration 0 / 10000: loss 2297.636549
# iteration 100 / 10000: loss 2.449606
# loss descent too slow 100 loss ago：2.441066364042734  loss:2.3958256555342143
# count: 5 -->localtime: Sat Jun 23 22:37:54 2018 <--- time: 25.002483129501343
# iterations_per_epoch:225.0 num_train:45000 batch_size:200 num_iters:10000
# iteration 0 / 10000: loss 2297.923932
# iteration 100 / 10000: loss 867.053708
# iteration 200 / 10000: loss 328.320999
# iteration 300 / 10000: loss 129.627339
# iteration 400 / 10000: loss 52.419056
# iteration 500 / 10000: loss 22.360480
# iteration 600 / 10000: loss 10.360393
# iteration 700 / 10000: loss 5.372706
# iteration 800 / 10000: loss 3.433232
# iteration 900 / 10000: loss 2.478703
# iteration 1000 / 10000: loss 2.070217
# loss descent too slow 100 loss ago：2.1777296133949218  loss:2.0946377533992724
# count: 6 -->localtime: Sat Jun 23 22:40:53 2018 <--- time: 178.86472606658936
# iterations_per_epoch:225.0 num_train:45000 batch_size:200 num_iters:10000
# iteration 0 / 10000: loss 2295.614187
# iteration 100 / 10000: loss 37.026403
# iteration 200 / 10000: loss 2.416145
# iteration 300 / 10000: loss 1.755100
# loss descent too slow 100 loss ago：1.8762927840041093  loss:1.8885066590019808
# count: 7 -->localtime: Sat Jun 23 22:41:32 2018 <--- time: 38.84980487823486
# iterations_per_epoch:225.0 num_train:45000 batch_size:200 num_iters:10000
# iteration 0 / 10000: loss 2296.280668
# iteration 100 / 10000: loss 1970.276124
# iteration 200 / 10000: loss 1691.444796
# iteration 300 / 10000: loss 1460.575565
# iteration 400 / 10000: loss 1263.616720
# iteration 500 / 10000: loss 1097.377396
# iteration 600 / 10000: loss 956.430509
# iteration 700 / 10000: loss 835.036870
# iteration 800 / 10000: loss 732.959341
# iteration 900 / 10000: loss 643.388548
# iteration 1000 / 10000: loss 568.484537
# iteration 1100 / 10000: loss 502.223229
# iteration 1200 / 10000: loss 445.916879
# iteration 1300 / 10000: loss 396.544774
# iteration 1400 / 10000: loss 353.583339
# iteration 1500 / 10000: loss 316.271521
# iteration 1600 / 10000: loss 283.351715
# iteration 1700 / 10000: loss 254.820345
# iteration 1800 / 10000: loss 229.363168
# iteration 1900 / 10000: loss 207.521720
# iteration 2000 / 10000: loss 187.705888
# iteration 2100 / 10000: loss 170.364195
# iteration 2200 / 10000: loss 154.993856
# iteration 2300 / 10000: loss 141.309694
# iteration 2400 / 10000: loss 129.178812
# iteration 2500 / 10000: loss 118.201853
# iteration 2600 / 10000: loss 108.517973
# iteration 2700 / 10000: loss 99.600545
# iteration 2800 / 10000: loss 91.863748
# iteration 2900 / 10000: loss 84.711155
# iteration 3000 / 10000: loss 78.479398
# iteration 3100 / 10000: loss 72.685262
# iteration 3200 / 10000: loss 67.481693
# iteration 3300 / 10000: loss 62.798410
# iteration 3400 / 10000: loss 58.566640
# iteration 3500 / 10000: loss 54.655803
# iteration 3600 / 10000: loss 51.035680
# iteration 3700 / 10000: loss 47.883058
# iteration 3800 / 10000: loss 44.804855
# iteration 3900 / 10000: loss 42.208847
# iteration 4000 / 10000: loss 39.618534
# iteration 4100 / 10000: loss 37.436959
# iteration 4200 / 10000: loss 35.257069
# iteration 4300 / 10000: loss 33.382141
# iteration 4400 / 10000: loss 31.608984
# iteration 4500 / 10000: loss 29.990799
# iteration 4600 / 10000: loss 28.442156
# iteration 4700 / 10000: loss 27.042403
# iteration 4800 / 10000: loss 25.671255
# iteration 4900 / 10000: loss 24.541780
# iteration 5000 / 10000: loss 23.378199
# iteration 5100 / 10000: loss 22.392698
# iteration 5200 / 10000: loss 21.336365
# iteration 5300 / 10000: loss 20.519361
# iteration 5400 / 10000: loss 19.647060
# iteration 5500 / 10000: loss 18.879749
# iteration 5600 / 10000: loss 18.169684
# iteration 5700 / 10000: loss 17.393216
# iteration 5800 / 10000: loss 16.751679
# iteration 5900 / 10000: loss 16.204666
# iteration 6000 / 10000: loss 15.585781
# iteration 6100 / 10000: loss 15.178588
# iteration 6200 / 10000: loss 14.577634
# iteration 6300 / 10000: loss 14.096243
# iteration 6400 / 10000: loss 13.603811
# iteration 6500 / 10000: loss 13.282961
# iteration 6600 / 10000: loss 12.907475
# iteration 6700 / 10000: loss 12.474525
# iteration 6800 / 10000: loss 12.122347
# iteration 6900 / 10000: loss 11.763950
# iteration 7000 / 10000: loss 11.535413
# loss descent too slow 100 loss ago：11.461206757513246  loss:11.383101481994709
# count: 8 -->localtime: Sat Jun 23 23:04:30 2018 <--- time: 1378.0700426101685
# iterations_per_epoch:225.0 num_train:45000 batch_size:200 num_iters:10000
# iteration 0 / 10000: loss 2296.465363
# iteration 100 / 10000: loss 1059.263593
# iteration 200 / 10000: loss 489.676956
# iteration 300 / 10000: loss 233.535940
# iteration 400 / 10000: loss 112.947649
# iteration 500 / 10000: loss 56.132897
# iteration 600 / 10000: loss 28.939505
# iteration 700 / 10000: loss 15.492152
# iteration 800 / 10000: loss 8.804952
# iteration 900 / 10000: loss 5.476845
# iteration 1000 / 10000: loss 3.814064
# iteration 1100 / 10000: loss 2.926606
# iteration 1200 / 10000: loss 2.389845
# iteration 1300 / 10000: loss 2.213072
# loss descent too slow 100 loss ago：2.2373959360478386  loss:2.144017281081098
# count: 9 -->localtime: Sat Jun 23 23:08:53 2018 <--- time: 262.9557406902313

# %%
for lr,rs,acc_train, acc_val, std_dev, learning_rate_decay in sorted(results):
    lr,rs,acc_train, acc_val, std_dev, learning_rate_decay = results[(lr,rs,acc_train, acc_val, std_dev, learning_rate_decay)]
    print('lr ', lr, ' reg ', rs, ' train_accuracy: ', acc_train, ' val_accuracy: ', acc_val, ' std_dev: ', std_dev, ' learning_rate_decay: ', learning_rate_decay)
print('best_val:', best_val)
print('best_hidden1', best_hidden1)
print('best_hidden2', best_hidden2)
print('best_hidden3', best_hidden3)
print('best_lr', best_lr)
print('best_rg', best_rg)
print('best_std_dev', best_std_dev)
print('best_learning_rate_decay:', best_learning_rate_decay)
# Out:
# lr  0.0011147389146156884  reg  0.5  train_accuracy:  0.29  val_accuracy:  0.34  std_dev:  0.05  learning_rate_decay:  0.95
# lr  0.001607024845439642  reg  0.5  train_accuracy:  0.255  val_accuracy:  0.3275  std_dev:  0.05  learning_rate_decay:  0.95
# lr  0.0032969309630489804  reg  0.5  train_accuracy:  0.135  val_accuracy:  0.135  std_dev:  0.05  learning_rate_decay:  0.95
# lr  0.008141870534348217  reg  0.5  train_accuracy:  0.115  val_accuracy:  0.115  std_dev:  0.05  learning_rate_decay:  0.95
# lr  0.008298434215562797  reg  0.5  train_accuracy:  0.14  val_accuracy:  0.0825  std_dev:  0.05  learning_rate_decay:  0.95
# lr  0.008891439005254397  reg  0.5  train_accuracy:  0.11  val_accuracy:  0.155  std_dev:  0.05  learning_rate_decay:  0.95
# lr  0.010254187845533936  reg  0.5  train_accuracy:  0.125  val_accuracy:  0.1025  std_dev:  0.05  learning_rate_decay:  0.95
# lr  0.04364522528104625  reg  0.5  train_accuracy:  0.125  val_accuracy:  0.095  std_dev:  0.05  learning_rate_decay:  0.95
# lr  0.28153113969962923  reg  0.5  train_accuracy:  0.11  val_accuracy:  0.0875  std_dev:  0.05  learning_rate_decay:  0.95
# lr  0.3173230256528172  reg  0.5  train_accuracy:  0.08  val_accuracy:  0.0825  std_dev:  0.05  learning_rate_decay:  0.95
# best_val: 0.34
# best_hidden1 1024
# best_hidden2 512
# best_hidden3 256
# best_lr 0.0011147389146156884
# best_rg 0.5
# best_std_dev 0.05
# best_learning_rate_decay: 0.95

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.0994

# %%
for net in node_net:
    test_acc = (net.predict(X_test) == y_test).mean()
    print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.1202
# Test accuracy:  0.0994
# Test accuracy:  0.3252
# Test accuracy:  0.1024
# Test accuracy:  0.1016
# Test accuracy:  0.1024
# Test accuracy:  0.0994
# Test accuracy:  0.0994
# Test accuracy:  0.2948
# Test accuracy:  0.0994
